# %% [markdown]
# <a href="https://colab.research.google.com/github/savinkakeysaa2025-afk/KKA-X-Semester1-/blob/main/App_bangun_tabung_Savinka_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# progam menghitung volume tabung

# meminta input dari pengguna
r = float(input("masukkan jari jari alas (cm): "))
t = float(input("masukkan tinggi tabung (cm): "))
pi = 3.14

# menghitung volume tabung
Volume = pi * r**2 * t

# menampilkan hasil
print(f"volume tabung adalah: {Volume} cm^3")
# Out:
# masukkan jari jari alas (cm): 15
# masukkan tinggi tabung (cm): 45
# volume tabung adalah: 31792.5 cm^3
