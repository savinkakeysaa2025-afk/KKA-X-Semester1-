# %% [markdown]
# <a href="https://colab.research.google.com/github/savinkakeysaa2025-afk/KKA-X-Semester1-/blob/main/Tipe_variabel_savinka_KS_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:savinka keysa salsabilla
#
# kelas:X.5
#
# No.absen:36

# %% [markdown]
# #konsep dasar variabel

# %%
print("savinkakeysaa.2025@gmail.com")
print("savinkakeysaa.2025@gmail.com")
print("savinkakeysaa.2025@gmail.com")
# Out:
# savinkakeysaa.2025@gmail.com
# savinkakeysaa.2025@gmail.com
# savinkakeysaa.2025@gmail.com

# %%
email_user_1 = "savinkakeysaa.2025@gmail.com"


print(email_user_1)
print(email_user_1)
# Out:
# savinkakeysaa.2025@gmail.com
# savinkakeysaa.2025@gmail.com

# %% [markdown]
# #peraturan penulisan variabel

# %%
email user 2 = "keysaaaa@gmail.com"




print(email user 2)
# Out:
#   File "/tmp/ipython-input-3005208082.py", line 1
#     email user 2 = "keysaaaa@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 = "keysaa@gmail.com"

print(emailuser2)
# Out:
# keysaa@gmail.com

# %%
email_user_2 = "kayyess@gmail.com"

print(email_user_2)
# Out:
# kayyess@gmail.com

# %%
3_email_user = "kyyesssa@gmail.com"


print(3_email_user)
# Out:
#   File "/tmp/ipython-input-1279859867.py", line 1
#     3_email_user = "kyyesssa@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "kayessaa@gmail.com"


print(email_user_3)
# Out:
# kayessaa@gmail.com

# %%
from ast import IfExp
if = "kayesssa@gmail.com"


print(if)
# Out:
#   File "/tmp/ipython-input-548869675.py", line 2
#     if = "kayesssa@gmail.com"
#        ^
# SyntaxError: invalid syntax

# %%
IF = "kayyesa@gmail.com"


print(IF)
# Out:
# kayyesa@gmail.com

# %%
print = "kyesss@gmail.com"


print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-840891784.py in <cell line: 0>()
#       2
#       3
# ----> 4 print(print)
#
# TypeError: 'str' object is not callable

# %%
_ = "kayesaa@gmail.com"



print(_)
# Out:
# kayesaa@gmail.com

# %%
print(_)
# Out:
# kayesaa@gmail.com

# %%
email_user_4 = "kkyes@gmail.com"


print(email_user_4)
# Out:
# kkyes@gmail.com

# %% [markdown]
# #jenis tipe variabel pada phyton

# %%
#float
x = 17.5
print(x)
type(x)
# Out:
# 17.5
# float

# %%
#string
z = "shinta"
print(z)
type(z)
# Out:
# shinta
# str

# %%
#integer
y = 8
print(y)
type(y)
# Out:
# 8
# int

# %%
r = -2.5
print(r)
type(r)
# Out:
# -2.5
# float

# %%
s = 5.1
print(s)
type(s)
# Out:
# 5.1
# float

# %%
k = '%7akh3.'
print(k)
type(k)
# Out:
# %7akh3.
# str

# %% [markdown]
# #Mengubah tipe data

# %%
a = 25
print(a)
type(a)
# Out:
# 25
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 25.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 25.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = True
print(b)
type(b)
# Out:
# True
# bool

# %%
b = int(b)
print(b)
type(b)
# Out:
# 1
# int

# %%
b = float (b)
print(b)
type(b)
# Out:
# 1.0
# float

# %%
b = str(b)
print(b)
type(b)
# Out:
# 1.0
# str

# %%
c = False
print(c)
type(c)
# Out:
# False
# bool

# %%
c = float(c)
print(c)
type(c)
# Out:
# 0.0
# float

# %%
c = int(c)
print(c)
type(c)
# Out:
# 0
# int

# %%
c = str (c)
print(c)
type(c)
# Out:
# 0
# str

# %%
#boolean
p = True
print(p)
type(p)
# Out:
# True
# bool

# %% [markdown]
# #Operator perbandingan

# %%
print(6>0)
# Out:
# True
